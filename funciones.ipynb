# %%
import pandas as pd

def main(df,ruta_archivo):
    # llama a la función que deseas utilizar    
    guardar_excel(df, ruta_archivo)
if __name__ == '__main__':
    main(df,ruta_archivo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Administrador\Desktop\jupyter\Planes\funciones.ipynb Cell 1 in 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrador/Desktop/jupyter/Planes/funciones.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     guardar_excel(df, ruta_archivo)
#       <a href='vscode-notebook-cell:/c%3A/Users/Administrador/Desktop/jupyter/Planes/funciones.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> if __name__ == '__main__':
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Administrador/Desktop/jupyter/Planes/funciones.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>     main(df,ruta_archivo)
#
# NameError: name 'df' is not defined

# %%
def guardar_excel(df, ruta_archivo):
        writer = pd.ExcelWriter(ruta_archivo)
        df.to_excel(writer, 'Sheet1', index=False)
        writer.save()

# %%
import pandas as pd

class Funciones:
    def guardar_excel(self, df, ruta_archivo):
        writer = pd.ExcelWriter(ruta_archivo)
        df.to_excel(writer, 'Sheet1', index=False)
        writer.save()
