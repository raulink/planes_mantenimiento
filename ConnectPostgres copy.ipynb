# %% [markdown]
# ## Conexion a base de datos
#
# Para la conexion a la base de datos
#
# conda install -c conda-forge psycopg2-binary

# %%
# %pip install psycopg2

# %% [markdown]
# # Verificar Paquetes instalados
#
# Pasos extraccion

# %%
# %load_ext sql

# %%
from sqlalchemy import create_engine

# %%
# %sql postgresql://postgres:postgres@192.168.0.107/db_maintenance

# %%
engine = create_engine('postgresql://postgres:postgres@192.168.0.107/db_mantenaince')

# %%
# %sql delete from activity_plan
# %sql delete from plans
# Out:
#  * postgresql://postgres:***@192.168.0.107/db_maintenance
# 1424 rows affected.
#  * postgresql://postgres:***@192.168.0.107/db_maintenance
# 199 rows affected.
# []

# %% [markdown]
# Instalacion de paquetes necesarios
# Pandas
# numpy
#
# Por alguna razon no permite la instalacion de los paquetes que se necesitan, es necesario la instalacion mediante el comando
# conda install -c conda-forge psycopg2-binary
#
# Se prueba con:
# conda install pandas

# %%
import sys  
# !{sys.executable} -m pip install pandas
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 23.1
# [notice] To update, run: C:\Users\Administrador\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# Verificar la ruta de instalacion de python para la ejecucion

# %%
import numpy as np

# %%
inventory_df = pd.read_sql("SELECT * FROM systems",con=engine)
inventory_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:3361, in Engine._wrap_pool_connect(self, fn, connection)
#    3360 try:
# -> 3361     return fn()
#    3362 except dialect.dbapi.Error as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\pool\base.py:320, in Pool.connect(self)
#     313 """Return a DBAPI connection from the pool.
#     314
#     315 The connection is instrumented such that when its
#    (...)
#     318
#     319 """
# --> 320 return _ConnectionFairy._checkout(self)
#
# ...

# %%
import sqlalchemy

# %%
# %pip install psycopg2-binary
# Out:
# ...
#   Using cached psycopg2_binary-2.9.4-cp310-cp310-win_amd64.whl (1.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\Administrador\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\psycopg2\\_psycopg.cp310-win_amd64.pyd'
# Check the permissions.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
import psycopg2

# %%
import psycopg2
conn_string = "host='localhost' dbname='db_maintenance' user='postgres' password='postgres'"
conn = psycopg2.connect(conn_string)

# %% [markdown]
# In this syntax, replace “your_password” with the password that you created during the installation of PostgreSQL.  “5432” is the default PostgreSQL port number. You can check your port number from your configuration file, or from your GUI management tool such as PGAdmin.  First, visit the Properties of your server from your PGAdmin or an equivalent tool such as DBEAVER.
# Then, check the Connection tab, port number. In the figure below, the port number is 5433.
#
# Finally, replace “postgres_db” with “dvdrental” or the name of the database that you will access.

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/db_mantenaince')

# %% [markdown]
# 3- Install the Jupyter Notebook SQL-extension using either pip or conda on your console.
# - pip install ipython-sql
#
# Then, load the sql extension:

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# 4- Set up the connection:

# %%
# %%sql $engine.url
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %% [markdown]
# 5- Now, we can use the magic command %sql to query the tables in dvdrental DB. One of the tables in the dvdrental database is the actors table with four columns: actor_id, first_name, last_name, last_update. Let’s see the first and last names of actors ordered by the first name in an ascending order.

# %%
# %sql SELECT * from systems
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# In another query, let’s see the actor_ids and first names of the actors whose name is Ed.

# %% [markdown]
# If you would want to write your query on multiple lines, you can write your magic command with double percentage sign since the magic function spans a cell rather than a line as below.
# Make sure you write only SQL commands in the cell, and nothing else.

# %%
# %sql INSERT INTO public."systems" ("uuid", "code", "name", "is_active", "created_by", "updated_by", "deleted_by", "created_at", "updated_at", "deleted_at") VALUES (md5(now()::text)::uuid, 'ACC', 'ACCIONAMIENTO 3', 't', 1, 1, NULL, now(), now(), NULL);
# Out:
# UsageError: Line magic function `%sql` not found.

# %%
# %sql select * from systems
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql SELECT actor_id, first_name
# from actor
# WHERE first_name = 'Ed'
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# Now that you’ve got the basics down, you can start writing more complex queries to your PostgreSQL database and analyzing your data with your preferred techniques in a Jupyter notebook.

# %% [markdown]
# ## consultas con sqlalchemy

# %%
# %pip install sqlalchemy
# Out:
# ...
#   Using cached SQLAlchemy-1.4.42-cp310-cp310-win_amd64.whl (1.6 MB)
# ...
#      ------------------------------------ 102.0/102.0 kB 976.1 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy
import pandas as pd

# %%
engine = sqlalchemy.create_engine(
    sqlalchemy.engine.url.URL.create
    (
        drivername="postgresql",
        username="postgres",
        password="postgres",
        host="localhost",
        port="5432",
        database="db_maintenance",
    ),
    echo_pool=True,
)

# %%
print("connecting with engine " + str(engine))
# Out:
# connecting with engine Engine(postgresql://postgres:***@localhost:5432/db_maintenance)

# %%
connection = engine.connect()
query = "select * from systems"
df = pd.read_sql_query(query,connection)
df
# Out:
#     id                                  uuid code  \
# 0    1  241f23e6-fb81-44b9-aa7f-764f469ced96  ACC
# 1    2  9b1c3bdb-e119-466e-a5ea-af02c0331e50  FRE
# 2    3  f345f11e-f837-4b61-8a72-b14b77c0a7c9  HID
# 3    4  46fb0794-04cd-4a6d-9779-9779b6491b32  TVH
# 4    5  091bc7f2-6085-4f0b-8205-4f84236fc3c4  TCT
# 5    6  820446ff-dd51-47fd-b2e9-bbfcf52c3b82  EPR
# 6    7  087a7798-1ed7-4abf-a75d-3a779b6f4a7f  CLN
# 7    8  15d2bafb-2882-4404-bfaf-bd65856d6683  CYS
# 8    9  c2109e81-e91f-4465-b68e-4e0ab1a12417  OYM
# 9   10  52e9dd7d-47ab-4aa3-996b-ef0437c71fdd  LUB
# 10  11  ba6a40ed-99a2-4f76-90f9-ae29e1102a76  LIN
# 11  12  c7d75fb2-bcd0-41ec-8995-0d227d4088d5  VEH
# 12  13  c654deea-2ece-4b3d-ac64-8689a74b8516  BTN
# 13  14  b7bd0df6-ca7c-49a3-951a-b9156bb95f4e  SUM
# 14  15  7b678a3a-562e-4a4f-948a-ef9f8afe7418  TER
# 15  16  48540795-f7db-4d0b-9594-a49e9de26c3f  AVH
# 16  17  fe6f1607-8796-4341-9c2c-528c1aecdcf5  FUN
# 17  18  47ca8349-8c0b-4cae-b0a0-929ef541d68e  GEN
# ...

# %% [markdown]
# DESDE POSTGRESQL Ejemplo CRUD

# %%
import psycopg2
import json

# %%
credenciales = {
"dbname": "db_maintenance",
"user": "postgres",
"password": "postgres",
"host": "localhost",
"port": 5432
}
conexion = psycopg2.connect(**credenciales)

# %% [markdown]
# Insertar

# %%
consulta = "INSERT INTO systems (uuid, code, name, is_active, created_by, updated_by, deleted_by, created_at, updated_at, deleted_at) VALUES (md5(now()::text)::uuid, %s, %s, 't', 1, 1, NULL, now(), now(), NULL);"

# %%
with conexion.cursor() as cursor:
    conexion.cursor().execute(consulta,("ACC","ACCIONAMIENTO 5"))
    conexion.commit()
    conexion.close()

# %%
# %sql SELECT * FROM systems WHERE name LIKE 'ACCIONAMIENTO%'
# Out:
#  * postgresql://postgres:***@localhost:5432/db_maintenance
#    postgresql://postgres:***@localhost:5432/postgres
# 9 rows affected.
# [(1, UUID('241f23e6-fb81-44b9-aa7f-764f469ced96'), 'ACC', 'ACCIONAMIENTO', True, 1, 1, None, datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), None),
#  (19, UUID('5ed44d2c-1e91-47bf-bd76-cb79a2121f38'), 'ACC', 'ACCIONAMIENTO', True, 1, 1, None, datetime.datetime(2022, 10, 19, 16, 0, 51, 142510, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), datetime.datetime(2022, 10, 19, 16, 0, 51, 142510, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), None),
# ...

# %%
import psycopg2
credenciales = {
"dbname": "db_maintenance",
"user": "postgres",
"password": "postgres",
"host": "localhost",
"port": 5432
}
conexion = psycopg2.connect(**credenciales)

try:
    with conexion.cursor() as cursor:
        # En este caso no necesitamos limpiar ningún dato
        cursor.execute("SELECT * FROM systems LIMIT 5;")
        # Hacer un while, mientras fetchone no regrese None
        mascota = cursor.fetchone()
        while mascota:
            print(mascota)
            mascota = cursor.fetchone()
except psycopg2.Error as e:
    print("Ocurrió un error al consultar: ", e)
finally:
    conexion.close()
# Out:
# (1, '241f23e6-fb81-44b9-aa7f-764f469ced96', 'ACC', 'ACCIONAMIENTO', True, 1, 1, None, datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), None)
# (2, '9b1c3bdb-e119-466e-a5ea-af02c0331e50', 'FRE', 'FRENADO', True, 1, 1, None, datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), None)
# (3, 'f345f11e-f837-4b61-8a72-b14b77c0a7c9', 'HID', 'HIDRÁULICO', True, 1, 1, None, datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), datetime.datetime(2022, 5, 30, 12, 3, 48, 71000, tzinfo=datetime.timezone(datetime.timedelta(days=-1, seconds=72000))), None)
# ...

# %%
dato_raw = raw_input("Inserte")
print(dato_raw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [74], line 1
# ----> 1 dato_raw = raw_input("Inserte")
#       2 print(dato_raw)
#
# NameError: name 'raw_input' is not defined

# %%
# %sql postgresql://postgres:postgres@localhost:5432/db_maintenance

# %%
# %sql SELECT * FROM systems
# Out:
#  * postgresql://postgres:***@localhost:5432/db_maintenance
#    postgresql://postgres:***@localhost:5432/postgres
# (psycopg2.errors.SyntaxError) error de sintaxis en o cerca de «10»
# LINE 1: SELECT * FROM systems TOP 10
#                                   ^
#
# [SQL: SELECT * FROM systems TOP 10]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# ## Importar Datos desde hoja de calculo

# %%
import pandas as pd
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSJQAH5FKUce0CfWUWuyyetaGPvKo8DVQIziua_5RMcJztNiFCZHNlFeBibHdf_Vzizgz960dMTd34c/pub?gid=852288123&single=true&output=csv"
df = pd.read_csv(url)
# Mostrar el data frame
df
# Out:
#          INSTALACION SIGLA    SECCION SIGLA.1            PLANTA SIGLA.2  \
# 0         LINEA ROJA    RO        NaN     NaN               NaN     NaN
# 1         LINEA ROJA    RO  SECCION 1      S1               NaN     NaN
# 2         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 3         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 4         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# ...              ...   ...        ...     ...               ...     ...
# 2413  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2414  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2415  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2416  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2417  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
#
#                     AREA SIGLA.3  \
# 0                    NaN     NaN
# ...

# %%
#List of columns on datafram
df.columns.tolist()
# Out:
# ['INSTALACION',
#  'SIGLA',
#  'SECCION',
#  'SIGLA.1',
#  'PLANTA',
#  'SIGLA.2',
#  'AREA',
#  'SIGLA.3',
#  'OBSERVACIONES',
#  'TAG',
#  'Nombre actual',
#  'Nivel',
#  'Tiene fotografia',
#  'Auxiliares']

# %% [markdown]
# # Eliminar columnas innecesarias

# %%
df_total = df
df_total
# Out:
#          INSTALACION SIGLA    SECCION SIGLA.1            PLANTA SIGLA.2  \
# 0         LINEA ROJA    RO        NaN     NaN               NaN     NaN
# 1         LINEA ROJA    RO  SECCION 1      S1               NaN     NaN
# 2         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 3         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 4         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# ...              ...   ...        ...     ...               ...     ...
# 2413  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2414  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2415  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2416  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2417  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
#
#                     AREA SIGLA.3  \
# 0                    NaN     NaN
# ...

# %%
# if exist columns 'OBSERVACIONES','Nombre actual','Nivel'  delete it

df = df.drop(['OBSERVACIONES','Nombre actual','Tiene fotografia',  'Auxiliares'], axis=1, errors='ignore')
#df = pd.DataFrame({'row_num':[1,2], 'w':[3,4]})
#df = df.drop(['row_num','start_date','end_date','symbol'], axis=1, errors='ignore')
#Mostrar el listado de columnas
filas = df.columns.tolist()
print (type(filas))
# Out:
# <class 'list'>

# %%
df
# Out:
#          INSTALACION SIGLA    SECCION SIGLA.1            PLANTA SIGLA.2  \
# 0         LINEA ROJA    RO        NaN     NaN               NaN     NaN
# 1         LINEA ROJA    RO  SECCION 1      S1               NaN     NaN
# 2         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 3         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 4         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# ...              ...   ...        ...     ...               ...     ...
# 2413  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2414  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2415  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2416  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2417  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
#
#                     AREA SIGLA.3              TAG  Nivel
# ...

# %%
#Listado y recorrido por las columnas
i=0
for fila in filas:
    i+=1
    print(f"{i} => {fila} ")
# Out:
# 1 => INSTALACION
# 2 => SIGLA
# 3 => SECCION
# 4 => SIGLA.1
# 5 => PLANTA
# 6 => SIGLA.2
# 7 => AREA
# 8 => SIGLA.3
# 9 => TAG
# 10 => Nivel

# %% [markdown]
# ## Conteo de registros por niveles

# %%
# select rows with columns is not null in python?
print('Registros Nivel 3   :',len(df[df['Nivel']==3]))
print('Registros Nivel 4.1 :',len(df[df['Nivel']==4.1]))
print('Registros Nivel 4.2 :',len(df[df['Nivel']==4.2]))
print('Registros Nivel 5   :',len(df[df['Nivel']==5]))
# Out:
# Registros Nivel 3   : 10
# Registros Nivel 4.1 : 25
# Registros Nivel 4.2 : 159
# Registros Nivel 5   : 2224

# %% [markdown]
# ## Preparar inserción de nivel 3

# %%
# select rows with columns is not null in python?
df[df['TAG'].notnull()]

#df.query('security == security and comnam == comnam')

#df[not(df['TAG'].isnull())]
# Out:
#          INSTALACION SIGLA    SECCION SIGLA.1            PLANTA SIGLA.2  \
# 3         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 4         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 5         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 6         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 7         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# ...              ...   ...        ...     ...               ...     ...
# 2414  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2415  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2416  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2417  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2418  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
#
#                     AREA SIGLA.3              TAG
# 3                 PUENTE     PNT     RO-S1-M1-PNT
# ...

# %%
#Definir el nivel de agrupacion
df_sample =df.set_index(['INSTALACION','SECCION','PLANTA'])
df_sample.query('INSTALACION == "LINEA ROJA"')
#df_sample[df_sample['INSTALACION'] =='LINEA ROJA']
#df_sample.head(20)
# Out:
#                                            SIGLA SIGLA.1 SIGLA.2  \
# INSTALACION SECCION   PLANTA
# LINEA ROJA  NaN       NaN                     RO     NaN     NaN
#             SECCION 1 NaN                     RO      S1     NaN
#                       ESTACION MOTRIZ         RO      S1      M1
#                       ESTACION MOTRIZ         RO      S1      M1
#                       ESTACION MOTRIZ         RO      S1      M1
# ...                                          ...     ...     ...
#             EDIFICIOS ESTACIÓN 16 DE JULIO    RO     EDF     EJL
#                       ESTACIÓN 16 DE JULIO    RO     EDF     EJL
#                       ESTACIÓN 16 DE JULIO    RO     EDF     EJL
#                       ESTACIÓN 16 DE JULIO    RO     EDF     EJL
#                       ESTACIÓN 16 DE JULIO    RO     EDF     EJL
#
#                                                           AREA SIGLA.3  \
# INSTALACION SECCION   PLANTA
# ...

# %% [markdown]
# ## Trabajando con las filas

# %%
idx =df_sample.index
label = df_sample.index[0]
print(label)
print(idx)
# Out:
# ('LINEA ROJA', nan, nan)
# MultiIndex([(    'LINEA ROJA',         nan,                     nan),
#             (    'LINEA ROJA', 'SECCION 1',                     nan),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             (    'LINEA ROJA', 'SECCION 1',       'ESTACION MOTRIZ'),
#             ...
#             ('LINEA PLATEADA', 'EDIFICIOS', 'ESTACION FARO MURILLO'),
#             ('LINEA PLATEADA', 'EDIFICIOS', 'ESTACION FARO MURILLO'),
#             ('LINEA PLATEADA', 'EDIFICIOS', 'ESTACION FARO MURILLO'),
# ...

# %%
temp =  df_sample.values
print(type(temp))

# recorrer array en python
for i in temp:
  print(i)
# Out:
# <class 'numpy.ndarray'>
# ['RO' nan nan nan nan nan 3.0]
# ['RO' 'S1' nan nan nan nan 4.1]
# ['RO' 'S1' 'M1' nan nan nan 4.2]
# ['RO' 'S1' 'M1' 'PUENTE' 'PNT' 'RO-S1-M1-PNT' 5.0]
# ['RO' 'S1' 'M1' 'ANDEN' 'AND' 'RO-S1-M1-AND' 5.0]
# ['RO' 'S1' 'M1' 'FOSA' 'FOS' 'RO-S1-M1-FOS' 5.0]
# ['RO' 'S1' 'M1' 'SALA DE OPERACION' 'SOP' 'RO-S1-M1-SOP' 5.0]
# ['RO' 'S1' 'M1' 'SALA DE MAQUINAS' 'SMQ' 'RO-S1-M1-SMQ' 5.0]
# ['RO' 'S1' 'M1' 'ARMARIOS SISTEMA ELECTROMECANICO' 'ASE' 'RO-S1-M1-ASE'
#  5.0]
# ['RO' 'S1' 'M1' 'GENERADOR SISTEMA ELECTROMECANICO' 'GSE' 'RO-S1-M1-GSE'
#  5.0]
# ['RO' 'S1' 'R1' nan nan nan 4.2]
# ['RO' 'S1' 'R1' 'PUENTE' 'PNT' 'RO-S1-R1-PNT' 5.0]
# ['RO' 'S1' 'R1' 'ANDEN' 'AND' 'RO-S1-R1-AND' 5.0]
# ['RO' 'S1' 'R1' 'FOSA' 'FOS' 'RO-S1-R1-FOS' 5.0]
# ['RO' 'S1' 'R1' 'SALA DE OPERACION' 'SOP' 'RO-S1-R1-SOP' 5.0]
# ['RO' 'S1' 'TO' nan nan nan 4.2]
# ['RO' 'S1' 'TO' 'TORRE 1' 'T1' 'RO-S1-TO-T1' 5.0]
# ['RO' 'S1' 'TO' 'TORRE 2' 'T2' 'RO-S1-TO-T2' 5.0]
# ...

# %%
# select rows with columns is not null in python?
df[df['TAG'].notnull()]

#df.query('security == security and comnam == comnam')

#df[not(df['TAG'].isnull())]
# Out:
#          INSTALACION SIGLA    SECCION SIGLA.1            PLANTA SIGLA.2  \
# 3         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 4         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 5         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 6         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# 7         LINEA ROJA    RO  SECCION 1      S1   ESTACION MOTRIZ      M1
# ...              ...   ...        ...     ...               ...     ...
# 2414  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2415  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2416  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2417  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
# 2418  LINEA PLATEADA    PL  EDIFICIOS     EDF  ESTACION MIRADOR     EMR
#
#                     AREA SIGLA.3              TAG
# 3                 PUENTE     PNT     RO-S1-M1-PNT
# ...

# %%
# added 1 like string or 1 like number
filtered = df[df.iloc[:, 3:].isin(['0/1', '1', 1]).any(axis=1)]
# delete a column in python?
del df['column_name']
# Out:
# Docstring:
# %%python script magic
#
# Run cells with python in a subprocess.
#
# This is a shortcut for `%%script python`
# File:      c:\python310\lib\site-packages\ipython\core\magics\script.py

# %% [markdown]
# # Filtrar filas que contengan
# # Eliminar las filas que tengan TG NaN

# %%
df.query("(TAG (Atributos de Uso / Ubicación)")
# Out:
# ---------------------------------------------------------------------------
# TokenError                                Traceback (most recent call last)
# Cell In [120], line 1
# ----> 1 df.query("(TAG (Atributos de Uso / Ubicación)")
#
# File c:\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:4463, in DataFrame.query(self, expr, inplace, **kwargs)
#    4461 kwargs["level"] = kwargs.pop("level", 0) + 2
#    4462 kwargs["target"] = None
# -> 4463 res = self.eval(expr, **kwargs)
#    4465 try:
#    4466     result = self.loc[res]
#
# ...

# %%
# tamaño del data frame
df.shape
# Out:
# (829, 13)

# %%
df.keys()
# Out:
# Index(['INSTALACION (Nivel 3)', 'SIGLA', 'UNIDAD / SECCION (Nivel 4.1)',
#        'SIGLA.1', 'PLANTA / TIPO ESTACION \n(Nivel 4.2)', 'SIGLA.2',
#        'AREA (Nivel 5)', 'SIGLA.3', 'OBSERVACIONES',
#        'TAG (Atributos de Uso / Ubicación)', 'Nombre actual', 'Verificado',
#        'Tiene fotografia'],
#       dtype='object')

# %%
df.describe()
# Out:
#        INSTALACION (Nivel 3) SIGLA UNIDAD / SECCION (Nivel 4.1) SIGLA.1  \
# count                    814   727                          798     802
# unique                    10     9                            5       4
# top               LINEA AZUL    AZ                    SECCION 1      S1
# freq                     100   106                          286     290
#
#        PLANTA / TIPO ESTACION \n(Nivel 4.2) SIGLA.2 AREA (Nivel 5) SIGLA.3  \
# count                                   585     777            602     601
# unique                                   48      44             90      70
# top                         ESTACION MOTRIZ      M1         PUENTE     PNT
# freq                                    112     163             44      44
#
#        OBSERVACIONES TAG (Atributos de Uso / Ubicación)     Nombre actual  \
# count            154                                601               124
# unique            81                                600                45
# ...

# %%
# Valores unicos de las columnas
df['SIGLA'].unique()
# Out:
# array(['RO', 'AM', nan, 'VE', 'AZ', 'BL', 'CE', 'MO', 'CA', 'PL'],
#       dtype=object)

# %%
list(df)
# Out:
# ['INSTALACION (Nivel 3)',
#  'SIGLA',
#  'UNIDAD / SECCION (Nivel 4.1)',
#  'SIGLA.1',
#  'PLANTA / TIPO ESTACION \n(Nivel 4.2)',
#  'SIGLA.2',
#  'AREA (Nivel 5)',
#  'SIGLA.3',
#  'OBSERVACIONES',
#  'TAG (Atributos de Uso / Ubicación)',
#  'Nombre actual',
#  'Verificado',
#  'Tiene fotografia']

# %%
df.drop(['OBSERVACIONES'],axis=1,inplace=True)

# %%
df_sample =df.set_index(['INSTALACION (Nivel 3)','UNIDAD / SECCION (Nivel 4.1)','PLANTA / TIPO ESTACION \n(Nivel 4.2)','AREA (Nivel 5)'])
#df_sample.head(20)

# %%
df_sample.loc['LINEA ROJA',:]
# Out:
#                                                                                      SIGLA  \
# UNIDAD / SECCION (Nivel 4.1) PLANTA / TIPO ESTACION \n(Nivel 4.2) AREA (Nivel 5)
# NaN                          NaN                                  NaN                   RO
# SECCION 1                    NaN                                  NaN                   RO
#                              ESTACION MOTRIZ                      NaN                   RO
#                                                                   PUENTE                RO
#                                                                   ANDEN                 RO
# ...                                                                                    ...
# EDIFICIOS                    NaN                                  GENERADOR EDIFICIO    RO
#                                                                   SALA DE VIGILANCIA    RO
# ...

# %%
df_test = df_sample[idx_filtro]
